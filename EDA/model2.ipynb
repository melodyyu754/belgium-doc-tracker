# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('world_bank_data.csv')

# Selecting features
X = df[['protests per capita', 'gdp per capita']]

# Normalizing features
X = (X - X.mean()) / X.std()

# K-means clustering
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
df['cluster'] = kmeans.predict(X)

# outputs clusters with the countries in them
for cluster in range(3):
    print(f'Cluster {cluster}')
    print(df[df['cluster'] == cluster]['country'].values)
    print()

# plots the clusters, gdp per capita vs protests per capita
plt.scatter(df['gdp per capita'], df['protests per capita'], c=df['cluster'])
plt.xlabel('GDP per capita')
plt.ylabel('Protests per capita')
# include a legend for the clusters
plt.show()
# Out:
# Cluster 0
# ['Albania' 'Argentina' 'Chile' 'Colombia' 'Costa Rica' 'Croatia' 'Estonia'
#  'Greece' 'Hungary' 'Jamaica' 'Kosovo' 'Latvia' 'Lithuania' 'Mexico'
#  'Mongolia' 'Poland' 'Portugal' 'Serbia' 'Slovenia' 'Uruguay']
#
# Cluster 1
# ['Australia' 'Austria' 'Belgium' 'Canada' 'Denmark' 'Finland' 'Germany'
#  'Iceland' 'Ireland' 'Luxembourg' 'Netherlands' 'Norway' 'Singapore'
#  'Switzerland' 'United Kingdom' 'United States']
#
# Cluster 2
# ['India']
